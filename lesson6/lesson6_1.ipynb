# %%
import time


def my_function():
    t1 = time.time()
    t2 = time.time()
    
    print(type(t1))

def main_sync():
    my_function()
    pass


if __name__ == "__main__":
    main_sync()
# Out:
# <class 'float'>

# %%
import time

def my_function():
    time.sleep(1)


t1 = time.time()
my_function()
t2 = time.time()

print(type(t1))

print(t2-t1)
# Out:
# <class 'float'>
# 1.0004010200500488

# %%
import time


print(type(time))
# Out:
# <class 'module'>
