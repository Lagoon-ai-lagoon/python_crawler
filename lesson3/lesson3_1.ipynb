# %%
chinese = 78
english = 93
math = 73


total = chinese + english + math
print("total = ",total)
# Out:
# total =  244

# %%
"total=" + "100"
"="*60
# Out:
# '============================================================'

# %%
apple = 6
orange = 9

print("蘋果=" + str(apple)+"個，橘子" +str(orange)+"個")
# Out:
# 蘋果=6個，橘子9個

# %%
# 字串和變數的整合
apple = int(input("請輸入蘋果的數量:"))
orange = int(input("請輸入橘子的數量:"))

print("蘋果=" + str(apple) + "個,橘子=" + str(orange) + "個")
# Out:
# 蘋果=99個,橘子=990個

# %%
car = int(input("幾台車："))

print("有"+ str(car) +"台車")
# Out:
# 有89台車

# %%
# str template
# 字串插補變數
# 字串和變數整合,傳出1個全新的字串




print(f"蘋果={apple}個,橘子={orange}個")
# Out:
# 蘋果=99個,橘子=990個
