# %%
age = 17


if age >=18:
    print("可以考駕照")

else:
    print("不可以考駕照，太年輕了！")
# Out:
# 不可以考駕照，太年輕了！

# %%
#巢狀判斷

age =55


if age < 18:
    print("屁孩")
else:
    if age < 40:
        print("青年")
    else:
        print("壯年")
# Out:
# 壯年

# %%
#多項選擇

age =17


if age < 18:
    print("屁孩")
elif age < 40:
    print("青年")
else:
    print("壯年")
# Out:
# 屁孩

# %%
score = 59

if score >=90:
    print("優")



elif score >=80:
    print("甲")

elif score >=70:
    print("乙")

elif score >=60:
    print("丙")
else:
        print("丁")
# Out:
# 丁

# %%
score = 89

if score >=90:
    print("優")

elif  score<90 and score >=80:
    print("甲")

elif score <80 and score >=70:
    print("乙")

elif score < 70 and score >=60:
    print("丙")
else:
        print("丁")
# Out:
# 甲

# %%
score = 89

if score >=90:
    print("優")

elif 90 > score >=80:
    print("甲")

elif 80 > score >=70:
    print("乙")

elif 70 > score >=60:
    print("丙")
else:
        print("丁")
